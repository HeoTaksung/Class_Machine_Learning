# %%
from sklearn.linear_model import LinearRegression

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

train_dataset = pd.read_csv('./Data/train_dataset_Water-factor.csv')
train_data = train_dataset.values

test_dataset = pd.read_csv('./Data/test_dataset_Water-factor.csv')
test_data = test_dataset.values

train_X = train_data[:, 0:-1].astype(float)
train_Y = train_data[:, [-1]]
test_X = test_data[:, 0:-1].astype(float)
test_Y = test_data[:, [-1]]

model = LinearRegression()
model.fit(train_X, train_Y)

y_predict = model.predict(test_X)

print("정답 : ",test_Y)
print("예측값 : ",y_predict)

plt.scatter(train_X, train_Y, color = 'red')
plt.title("Train data set")
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

plt.scatter(test_X, test_Y, color = 'red')
plt.plot(test_X, y_predict, color = 'blue')
plt.title("Test data set")
plt.xlabel('X')
plt.ylabel('Y')
plt.show()
# Out:
# 정답 :  [[133.]
#  [ 53.]
#  [ 56.]
#  [113.]
#  [ 35.]
#  [125.]
#  [ 76.]
#  [ 48.]
#  [147.]
#  [117.]
#  [182.]
#  [ 87.]]
# 예측값 :  [[183.4144407 ]
#  [160.37870362]
#  [153.79706445]
#  [166.96034278]
#  [143.92460571]
#  [176.83280153]
#  [180.12362111]
#  [140.63378612]
#  [163.6695232 ]
#  [199.86853861]
#  [186.70526028]
#  [180.12362111]]

# %%
from sklearn.linear_model import LinearRegression

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

train_dataset = pd.read_csv('./Data/train_dataset_Iris-Setosa.csv')
train_data = train_dataset.values

test_dataset = pd.read_csv('./Data/test_dataset_Iris-Setosa.csv')
test_data = test_dataset.values

train_X = train_data[:, 0:-1].astype(float)
train_Y = train_data[:, [-1]]
test_X = test_data[:, 0:-1].astype(float)
test_Y = test_data[:, [-1]]

model = LinearRegression()
model.fit(train_X, train_Y)

y_predict = model.predict(test_X)

print("정답 : ",test_Y)
print("예측값 : ",y_predict)

plt.scatter(train_X, train_Y, color = 'red', s=10)
plt.title("Train data")
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

plt.scatter(test_X, test_Y, color = 'red', s=10)
plt.plot(test_X, y_predict, color = 'blue')
plt.title("Test data")
plt.xlabel('X')
plt.ylabel('Y')
plt.show()
# Out:
# 정답 :  [[5.4]
#  [5.2]
#  [5.5]
#  [4.9]
#  [5. ]
#  [5.5]
#  [4.9]
#  [4.4]
#  [5.1]
#  [5. ]
#  [4.5]
#  [4.4]
#  [5. ]
#  [5.1]
#  [4.8]
#  [4.6]
#  [5.3]
#  [5. ]]
# 예측값 :  [[4.98204144]
#  [5.56774751]
#  [5.6514198 ]
#  [4.73102456]
#  [4.81469685]
#  [5.06571374]
#  [5.14938603]
#  [4.64735226]
#  [4.98204144]
#  [5.06571374]
#  [4.0616462 ]
#  [4.81469685]
#  [5.06571374]
#  [5.31673062]
#  [4.64735226]
#  [5.31673062]
#  [5.23305833]
#  [4.89836915]]

# %%
from sklearn.linear_model import LinearRegression

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

train_dataset = pd.read_csv('./Data/train_dataset_Kaggle.csv')
train_data = train_dataset.values

test_dataset = pd.read_csv('./Data/test_dataset_Kaggle.csv')
test_data = test_dataset.values

train_X = train_data[:, 0:-1].astype(float)
train_Y = train_data[:, [-1]]
test_X = test_data[:, 0:-1].astype(float)
test_Y = test_data[:, [-1]]

model = LinearRegression()
model.fit(train_X, train_Y)

y_predict = model.predict(test_X)

print("정답 : ",test_Y)
print("예측값 : ",y_predict)

plt.scatter(train_X, train_Y, color = 'red', s=10)
plt.title("Train data")
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

plt.scatter(test_X, test_Y, color = 'red', s=10)
plt.plot(test_X, y_predict, color = 'blue')
plt.title("Test data")
plt.xlabel('X')
plt.ylabel('Y')
plt.show()
# Out:
# 정답 :  [[ 79.77515201]
#  [ 23.17727887]
#  [ 25.60926156]
#  [ 17.85738813]
#  [ 41.84986439]
#  [  9.80523488]
#  [ 58.87465933]
#  [ 97.61793701]
#  [ 18.39512747]
#  [  8.74674765]
#  [  2.81141583]
#  [ 17.09537241]
#  [ 95.14907176]
#  [ 61.38800663]
#  [ 40.24701716]
#  [ 14.82248589]
#  [ 66.95806869]
#  [ 16.63507984]
#  [ 90.65513736]
#  [ 77.22982636]
#  [ 92.11906278]
#  [ 46.91387709]
#  [ 89.82634442]
#  [ 21.71380347]
#  [ 97.41206981]
#  [ 57.01631363]
#  [ 78.31056542]
#  [ 19.1315097 ]
#  [ 93.03483388]
#  [ 26.59112396]
#  [ 97.55155344]
#  [ 31.43524822]
#  [ 35.12724777]
#  [ 78.61042432]
#  [ 33.07112825]
#  [ 51.69967172]
#  [ 53.62235225]
#  [ 69.46306072]
#  [ 27.42497237]
#  [ 36.34644189]
#  [ 95.06140858]
#  [ 68.16724757]
#  [ 50.96155532]
#  [ 78.04237454]
#  [  5.60766487]
#  [ 36.11334779]
#  [ 67.2352155 ]
#  [ 65.01324035]
#  [ 38.14753871]
#  [ 34.31141446]
#  [ 95.28503937]
#  [ 87.84749912]
#  [ 54.08170635]
#  [ 31.93063515]
#  [ 59.61247085]
#  [ -1.04011421]
#  [ 47.49374765]
#  [ 62.60089773]
#  [ 70.9146434 ]
#  [ 56.14834113]
#  [ 14.05572877]
#  [ 68.11367147]
#  [ 75.59701346]
#  [ 59.225745  ]
#  [ 85.45504157]
#  [ 17.76197116]
#  [ 38.68888682]
#  [ 50.96343637]
#  [ 51.83503872]
#  [ 17.0761107 ]
#  [ 46.56141773]
#  [ 10.34754461]
#  [ 77.91032969]
#  [ 50.17008622]
#  [ 13.25690647]
#  [ 31.32274932]
#  [ 73.9308764 ]
#  [ 74.45114379]
#  [ 52.01932286]
#  [ 83.68820499]
#  [ 70.3698748 ]
#  [ 23.44479161]
#  [ 49.83051801]
#  [ 49.88226593]
#  [ 41.04525583]
#  [ 33.37834391]
#  [ 81.29750133]
#  [105.5918375 ]
#  [ 56.82457013]
#  [ 48.67252645]
#  [ 67.02150613]
#  [ 38.43076389]
#  [ 58.61466887]
#  [ 89.12377509]
#  [ 60.9105427 ]
#  [ 13.83959878]
#  [ 16.89085185]
#  [ 84.06676818]
#  [ 70.34969772]
#  [ 33.38474138]
#  [ -1.63296825]
#  [ 88.54475895]
#  [ 17.44047622]
#  [ 75.69298554]
#  [ 41.97607107]
#  [ 12.59244741]
#  [  0.27530726]
#  [ 98.13258005]
#  [ 87.45721555]
#  [ -2.34473854]
#  [ 39.3294153 ]
#  [ 16.68715211]
#  [ 96.58888601]
#  [ 97.70342201]
#  [ 67.01715955]
#  [ 25.63476257]
#  [ 13.41310757]
#  [ 95.15647284]
#  [  9.74416426]
#  [ -3.46788379]
#  [ 62.82816355]
#  [ 97.27405461]
#  [ 95.58017185]
#  [  7.46850184]
#  [ 45.44599591]
#  [ 46.69013968]
#  [ 74.4993599 ]
#  [ 21.63500655]
#  [ 91.59548851]
#  [ 26.49487961]
#  [ 67.38654703]
#  [ 74.25362837]
#  [ 12.07991648]
#  [ 21.32273728]
#  [ 29.31770045]
#  [ 26.48713683]
#  [ 68.94699774]
#  [ 59.10598995]
#  [ 64.37521087]
#  [ 60.20758349]
#  [ 70.34329706]
#  [ 97.1082562 ]
#  [ 75.7584178 ]
#  [ 10.80462727]
#  [ 12.11219941]
#  [ 63.28312382]
#  [ 98.03017721]
#  [ 63.19354354]
#  [ 34.8534823 ]
#  [ -2.81991397]
#  [ 59.8313966 ]
#  [ 29.38505024]
#  [ 97.00148372]
#  [ 85.18657275]
#  [ 61.74063192]
#  [ 18.84798163]
#  [ 78.79008525]
#  [ 95.12400481]
#  [ 30.48881287]
#  [ 10.41468095]
#  [ 38.98317436]
#  [ 46.11021062]
#  [ 52.45103628]
#  [ 21.16523945]
#  [ 52.28620611]
#  [ 44.18863945]
#  [ 97.13832018]
#  [ 67.22008001]
#  [ 18.98322306]
#  [ 24.3884599 ]
#  [ 79.44769523]
#  [ 40.03504862]
#  [ 53.32005764]
#  [ 54.55446979]
#  [ -2.7611826 ]
#  [ 37.80182795]
#  [ 57.48741435]
#  [ 36.06292994]
#  [ 49.83538167]
#  [ 74.68953276]
#  [ 14.86159401]
#  [101.0697879 ]
#  [ 99.43577876]
#  [ 91.69240746]
#  [ 34.12473248]
#  [  6.07939007]
#  [ 59.07247174]
#  [ 56.43046022]
#  [ 30.49412933]
#  [ 48.35172635]
#  [ 89.73153611]
#  [ 72.86282528]
#  [ 80.97144285]
#  [ 91.36566374]
#  [ 60.07137496]
#  [ 99.87382707]
#  [  8.65571417]
#  [ 69.39858505]
#  [ 19.38780134]
#  [ 53.11628433]
#  [ 78.39683006]
#  [ 25.75612514]
#  [ 75.07484683]
#  [ 92.88772282]
#  [ 69.45498498]
#  [ 13.12109842]
#  [ 48.09843134]
#  [ 79.3142548 ]
#  [ 68.48820749]
#  [ 73.2300846 ]
#  [ 24.68362712]
#  [ 41.90368917]
#  [ 62.22635684]
#  [ 45.96396877]
#  [ 23.52647153]
#  [ 51.80035866]
#  [ 51.10774273]
#  [ 95.79747345]
#  [  9.24113898]
#  [  7.64652976]
#  [  9.28169975]
#  [103.5266162 ]
#  [ 47.41006725]
#  [ 42.03835773]
#  [ 96.11982476]
#  [ 38.05766408]
#  [105.4503788 ]
#  [ 88.80306911]
#  [ 15.49301141]
#  [ 12.42624606]
#  [ 40.00709598]
#  [  5.6340309 ]
#  [ 87.36938931]
#  [ 89.73951993]
#  [ 66.61499643]
#  [ 72.9138853 ]
#  [ 57.19103506]
#  [ 11.21710477]
#  [  0.67607675]
#  [ 28.15668543]
#  [ 95.3958003 ]
#  [ 52.05490703]
#  [ 59.70864577]
#  [ 36.79224762]
#  [ 37.08457698]
#  [ 24.18437976]
#  [ 67.28725332]
#  [ 82.870594  ]
#  [ 89.899991  ]
#  [ 36.94173178]
#  [ 19.87562242]
#  [ 90.71481654]
#  [ 61.09367762]
#  [ 60.11134958]
#  [ 64.83296316]
#  [ 81.40381769]
#  [ 92.40217686]
#  [  2.57662538]
#  [ 63.80768172]
#  [ 38.67780759]
#  [ 16.82839701]
#  [ 99.78687252]
#  [ 44.68913433]
#  [ 71.00377824]
#  [ 51.57326718]
#  [ 19.87846479]
#  [ 79.50341495]
#  [ 34.58876491]
#  [ 55.7383467 ]
#  [ 68.19721905]
#  [ 55.81628509]
#  [  9.3914168 ]
#  [ 56.01448111]
#  [ 77.9969477 ]
#  [ 55.37049953]
#  [ 11.89457829]
#  [ 94.79081712]
#  [ 25.69041546]
#  [ 53.52042319]
#  [ 18.31396758]
#  [ 21.42637785]
#  [ 30.41303282]
#  [ 67.68142149]
#  [ 17.0854783 ]
#  [ 60.91792707]
#  [ 14.99514319]
#  [ 16.74923937]
#  [ 41.46923883]
#  [ 42.84526108]
#  [ 59.12912974]
#  [ 91.30863673]
#  [  8.67333636]
#  [ 39.31485292]
#  [  5.3136862 ]
#  [  5.40522052]
#  [ 68.5458879 ]
#  [ 47.33487629]
#  [ 54.09063686]
#  [ 63.29717058]
#  [ 52.45946688]]
# 예측값 :  [[76.94327594]
#  [20.90651855]
#  [21.90717494]
#  [19.90586217]
#  [35.91636428]
#  [14.90258026]
#  [61.93343021]
#  [94.95509081]
#  [19.90586217]
#  [ 4.89601644]
#  [ 3.89536006]
#  [18.90520579]
#  [95.95574719]
#  [61.93343021]
#  [35.91636428]
#  [14.90258026]
#  [64.93539936]
#  [13.90192388]
#  [86.94983976]
#  [68.93802488]
#  [88.95115252]
#  [50.92621001]
#  [88.95115252]
#  [26.91045685]
#  [96.95640358]
#  [57.93080468]
#  [78.9445887 ]
#  [20.90651855]
#  [92.95377805]
#  [26.91045685]
#  [98.95771634]
#  [30.91308237]
#  [32.91439514]
#  [79.94524508]
#  [27.91111323]
#  [46.92358448]
#  [52.92752277]
#  [68.93802488]
#  [27.91111323]
#  [32.91439514]
#  [90.95246528]
#  [70.93933765]
#  [49.92555363]
#  [75.94261956]
#  [ 3.89536006]
#  [36.91702066]
#  [69.93868127]
#  [67.9373685 ]
#  [39.91898981]
#  [34.9157079 ]
#  [93.95443443]
#  [87.95049614]
#  [51.92686639]
#  [30.91308237]
#  [58.93146107]
#  [-0.10726546]
#  [38.91833343]
#  [63.93474297]
#  [68.93802488]
#  [56.9301483 ]
#  [12.9012675 ]
#  [71.93999403]
#  [75.94261956]
#  [60.93277383]
#  [81.94655785]
#  [17.90454941]
#  [40.91964619]
#  [49.92555363]
#  [54.92883554]
#  [12.9012675 ]
#  [45.9229281 ]
#  [12.9012675 ]
#  [78.9445887 ]
#  [52.92752277]
#  [14.90258026]
#  [27.91111323]
#  [80.94590147]
#  [68.93802488]
#  [51.92686639]
#  [83.94787061]
#  [67.9373685 ]
#  [26.91045685]
#  [55.92949192]
#  [47.92424086]
#  [39.91898981]
#  [38.91833343]
#  [81.94655785]
#  [99.95837272]
#  [58.93146107]
#  [42.92095896]
#  [66.93671212]
#  [37.91767705]
#  [62.93408659]
#  [90.95246528]
#  [59.93211745]
#  [13.90192388]
#  [20.90651855]
#  [86.94983976]
#  [72.94065041]
#  [31.91373876]
#  [ 1.8940473 ]
#  [81.94655785]
#  [18.90520579]
#  [73.94130679]
#  [41.92030257]
#  [11.90061112]
#  [ 0.89339092]
#  [89.9518089 ]
#  [88.95115252]
#  [-0.10726546]
#  [40.91964619]
#  [15.90323665]
#  [93.95443443]
#  [96.95640358]
#  [65.93605574]
#  [23.9084877 ]
#  [16.90389303]
#  [89.9518089 ]
#  [12.9012675 ]
#  [-0.10726546]
#  [63.93474297]
#  [95.95574719]
#  [97.95705996]
#  [11.90061112]
#  [40.91964619]
#  [46.92358448]
#  [77.94393232]
#  [19.90586217]
#  [88.95115252]
#  [28.91176961]
#  [63.93474297]
#  [74.94196317]
#  [11.90061112]
#  [24.90914408]
#  [27.91111323]
#  [29.91242599]
#  [64.93539936]
#  [58.93146107]
#  [63.93474297]
#  [52.92752277]
#  [70.93933765]
#  [96.95640358]
#  [72.94065041]
#  [ 8.89864197]
#  [11.90061112]
#  [62.93408659]
#  [98.95771634]
#  [59.93211745]
#  [34.9157079 ]
#  [ 1.8940473 ]
#  [59.93211745]
#  [31.91373876]
#  [93.95443443]
#  [83.94787061]
#  [62.93408659]
#  [21.90717494]
#  [80.94590147]
#  [92.95377805]
#  [32.91439514]
#  [ 6.89732921]
#  [41.92030257]
#  [45.9229281 ]
#  [53.92817916]
#  [15.90323665]
#  [48.92489725]
#  [42.92095896]
#  [94.95509081]
#  [65.93605574]
#  [20.90651855]
#  [34.9157079 ]
#  [79.94524508]
#  [36.91702066]
#  [53.92817916]
#  [55.92949192]
#  [ 0.89339092]
#  [31.91373876]
#  [57.93080468]
#  [31.91373876]
#  [45.9229281 ]
#  [71.93999403]
#  [16.90389303]
#  [96.95640358]
#  [92.95377805]
#  [90.95246528]
#  [36.91702066]
#  [ 3.89536006]
#  [53.92817916]
#  [50.92621001]
#  [26.91045685]
#  [45.9229281 ]
#  [91.95312167]
#  [72.94065041]
#  [76.94327594]
#  [90.95246528]
#  [60.93277383]
#  [98.95771634]
#  [ 3.89536006]
#  [71.93999403]
#  [18.90520579]
#  [56.9301483 ]
#  [77.94393232]
#  [25.90980046]
#  [73.94130679]
#  [89.9518089 ]
#  [65.93605574]
#  [12.9012675 ]
#  [39.91898981]
#  [76.94327594]
#  [66.93671212]
#  [74.94196317]
#  [22.90783132]
#  [44.92227172]
#  [58.93146107]
#  [43.92161534]
#  [22.90783132]
#  [54.92883554]
#  [54.92883554]
#  [94.95509081]
#  [11.90061112]
#  [ 3.89536006]
#  [ 6.89732921]
#  [99.95837272]
#  [47.92424086]
#  [41.92030257]
#  [95.95574719]
#  [38.91833343]
#  [99.95837272]
#  [86.94983976]
#  [13.90192388]
#  [13.90192388]
#  [36.91702066]
#  [ 4.89601644]
#  [87.95049614]
#  [90.95246528]
#  [64.93539936]
#  [73.94130679]
#  [55.92949192]
#  [15.90323665]
#  [ 4.89601644]
#  [27.91111323]
#  [91.95312167]
#  [45.9229281 ]
#  [53.92817916]
#  [38.91833343]
#  [43.92161534]
#  [30.91308237]
#  [67.9373685 ]
#  [85.94918338]
#  [89.9518089 ]
#  [37.91767705]
#  [20.90651855]
#  [94.95509081]
#  [55.92949192]
#  [59.93211745]
#  [64.93539936]
#  [77.94393232]
#  [88.95115252]
#  [ 5.89667283]
#  [66.93671212]
#  [35.91636428]
#  [15.90323665]
#  [99.95837272]
#  [44.92227172]
#  [72.94065041]
#  [56.9301483 ]
#  [19.90586217]
#  [75.94261956]
#  [33.91505152]
#  [54.92883554]
#  [71.93999403]
#  [54.92883554]
#  [ 7.89798559]
#  [55.92949192]
#  [71.93999403]
#  [57.93080468]
#  [ 5.89667283]
#  [95.95574719]
#  [22.90783132]
#  [57.93080468]
#  [22.90783132]
#  [18.90520579]
#  [24.90914408]
#  [63.93474297]
#  [20.90651855]
#  [58.93146107]
#  [18.90520579]
#  [15.90323665]
#  [41.92030257]
#  [42.92095896]
#  [60.93277383]
#  [91.95312167]
#  [10.89995474]
#  [40.91964619]
#  [ 0.89339092]
#  [ 7.89798559]
#  [70.93933765]
#  [45.9229281 ]
#  [54.92883554]
#  [61.93343021]
#  [46.92358448]]
